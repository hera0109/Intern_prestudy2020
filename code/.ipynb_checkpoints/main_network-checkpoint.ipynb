# %%
import sys
import parse as p
import author_network as an
import numpy as np
import networkx as nx
import graphviz as gv
from matplotlib import pyplot as plt
from community import community_louvain
import collections
from node2vec import Node2Vec
p.parse_json('../data/icml2019.json')
p.parse_json('../data/icml2018.json')
p.parse_json('../data/icml2017.json')

# %% [markdown]
# ### Reading File

# %%
temp, temp1 = p.get_paper_count()
authors = temp[0]
counts = temp[1]
sorted_authors = temp1[0]
sorted_counts = temp1[1]

# %% [markdown]
# ### Author who published the most papers

# %%
fig = plt.figure(figsize=(14, 7))
ax = fig.add_axes([0,0,1,1])
ax.bar(sorted_authors[:10],sorted_counts[:10], width = 0.8)
plt.title('Top 10 Authors With Most Papers')
plt.savefig('../image/authors_with_most_papers.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ###  Author who has been working with the most people

# %%
co_count_authors, co_counts = an.co_worker_counts()
fig = plt.figure(figsize=(14, 7))
ax = fig.add_axes([0,0,1,1])
ax.bar(co_count_authors[:10],co_counts[:10], width = 0.8)
plt.title('Top 10 Authors Who Worked With Most Co-workers')
plt.savefig('../image/authors_working_with_most_people.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Community Detection (Louvain algorithm)

# %%
edges, alone = an.get_edges()
G = nx.MultiGraph()
G.add_edges_from(edges)
G.add_nodes_from(alone)
partition = community_louvain.best_partition(G)

# %%
# Adding number of papers attribute
for i in range(len(authors)):
    G.nodes[authors[i]]['papers'] = counts[i]

# %%
values = [partition.get(node) for node in G.nodes()]
counter = collections.Counter(values)

# %% [markdown]
# ### Author who has been working with the most research groups

# %%
other_group = an.find_other_group(G, values)
fig = plt.figure(figsize=(14, 7))
ax = fig.add_axes([0,0,1,1])
ax.bar([x[0] for x in other_group ][:10], [x[1] for x in other_group ][:10], width = 0.8)
plt.title('Top 10 Authors Who Worked With Other Research Group Most')
plt.savefig('../image/authors_with_most_research_groups_simple.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Network Graph - Louvain algorithm

# %%
plt.figure(figsize =(50,50))
sp = nx.spring_layout(G)
#node_size = [x for x in G.degree()]
node_size = [500 * nx.get_node_attributes(G, 'papers')[v] for v in G] 
nx.draw_networkx(G, pos=sp, with_labels=False, node_size=node_size,
                 node_color=values, alpha=0.7,cmap = plt.cm.ocean)
# plt.axes('off')
plt.savefig('../image/network_graph_Louvain.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Network Graph - node2vec and k-means algorithm

# %%
node2vec = Node2Vec(graph=G, # target graph
                    dimensions=50, # embedding dimension
                    walk_length=10, # number of nodes in each walks 
                    p = 1, # return hyper parameter
                    q = 0.0001, # inout parameter, q값을 작게 하면 structural equivalence를 강조하는 형태로 학습됩니다. 
                    weight_key=None, # if weight_key in attrdict 
                    num_walks=2000, 
                    workers=1,
                   )

# 대략 walk들이 어떻게 발생하는지를 아래처럼 볼 수도 있습니다. 
for i, each_walk in enumerate(node2vec.walks):
    print(f"{i:0>2d}, {each_walk}")
    if i>1:
        break

# 발생한 walk를 사용해서 학습을 시켜봅니다. 
# 여기서 fitting할때 사용하는 argument는 gensim의 word2vec과 같습니다. 
# 단 학습시킨 것을 model1처럼 어디에 집어넣어줘야 하는 것 같네요. 여기서 p나 q값을 조절하기는 어려운 것 같습니다. 
model1 = node2vec.fit(window=2)
# Out:
# Computing transition probabilities:   0%|          | 0/4571 [00:00<?, ?it/s]
#
#
# Computing transition probabilities:   4%|▎         | 167/4571 [00:00<00:02, 1669.80it/s]
#
#
# Computing transition probabilities:   9%|▉         | 414/4571 [00:00<00:02, 1848.23it/s]
#
#
# Computing transition probabilities:  14%|█▎        | 628/4571 [00:00<00:02, 1925.42it/s]
#
#
# Computing transition probabilities:  19%|█▉        | 861/4571 [00:00<00:01, 2029.45it/s]
#
#
# Computing transition probabilities:  23%|██▎       | 1063/4571 [00:00<00:01, 2023.11it/s]
#
#
# Computing transition probabilities:  29%|██▉       | 1331/4571 [00:00<00:01, 2183.59it/s]
#
#
# Computing transition probabilities:  36%|███▌      | 1629/4571 [00:00<00:01, 2372.53it/s]
#
#
# Computing transition probabilities:  43%|████▎     | 1944/4571 [00:00<00:01, 2561.95it/s]
#
#
# Computing transition probabilities:  49%|████▉     | 2243/4571 [00:00<00:00, 2676.01it/s]
#
#
# Computing transition probabilities:  57%|█████▋    | 2603/4571 [00:01<00:00, 2896.63it/s]
#
#
# Computing transition probabilities:  63%|██████▎   | 2900/4571 [00:01<00:00, 2877.04it/s]
#
#
# Computing transition probabilities:  72%|███████▏  | 3273/4571 [00:01<00:00, 3073.53it/s]
#
#
# Computing transition probabilities:  79%|███████▉  | 3601/4571 [00:01<00:00, 3128.50it/s]
#
#
# Computing transition probabilities:  88%|████████▊ | 4001/4571 [00:01<00:00, 3347.00it/s]
#
#
# Computing transition probabilities: 100%|██████████| 4571/4571 [00:01<00:00, 3024.23it/s]
#
#
#
# Generating walks (CPU: 1):   0%|          | 0/2000 [00:00<?, ?it/s]
#
#
# Generating walks (CPU: 1):   0%|          | 2/2000 [00:01<27:28,  1.21it/s]
#
#
# Generating walks (CPU: 1):   0%|          | 3/2000 [00:04<45:12,  1.36s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 4/2000 [00:05<48:53,  1.47s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 5/2000 [00:07<50:35,  1.52s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 6/2000 [00:09<52:14,  1.57s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 7/2000 [00:10<53:05,  1.60s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 8/2000 [00:12<54:06,  1.63s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 9/2000 [00:14<53:59,  1.63s/it]
#
#
# Generating walks (CPU: 1):   0%|          | 10/2000 [00:15<53:54,  1.63s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 11/2000 [00:17<53:48,  1.62s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 12/2000 [00:19<54:31,  1.65s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 13/2000 [00:20<54:03,  1.63s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 14/2000 [00:22<54:49,  1.66s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 15/2000 [00:24<54:28,  1.65s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 16/2000 [00:25<54:16,  1.64s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 17/2000 [00:27<53:58,  1.63s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 18/2000 [00:29<53:39,  1.62s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 19/2000 [00:30<53:26,  1.62s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 20/2000 [00:32<53:57,  1.64s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 21/2000 [00:33<54:08,  1.64s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 22/2000 [00:35<54:23,  1.65s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 23/2000 [00:37<54:45,  1.66s/it]
#
#
# Generating walks (CPU: 1):   1%|          | 24/2000 [00:39<56:54,  1.73s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-edf472d49274> in <module>
#       6                     weight_key=None, # if weight_key in attrdict
#       7                     num_walks=2000,
# ----> 8                     workers=1,
#       9                    )
#      10 print('start')
#
# /usr/local/lib/python3.7/site-packages/node2vec/node2vec.py in __init__(self, graph, dimensions, walk_length, num_walks, p, q, weight_key, workers, sampling_strategy, quiet, temp_folder)
#      65
#      66         self._precompute_probabilities()
# ---> 67         self.walks = self._generate_walks()
#      68
#      69     def _precompute_probabilities(self):
#
# /usr/local/lib/python3.7/site-packages/node2vec/node2vec.py in _generate_walks(self)
#     152                                              self.quiet) for
#     153             idx, num_walks
# --> 154             in enumerate(num_walks_lists, 1))
#     155
#     156         walks = flatten(walk_results)
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.7/site-packages/node2vec/parallel.py in parallel_generate_walks(d_graph, global_walk_length, num_walks, cpu_num, sampling_strategy, num_walks_key, walk_length_key, neighbors_key, probabilities_key, first_travel_key, quiet)
#      61                 else:
#      62                     probabilities = d_graph[walk[-1]][probabilities_key][walk[-2]]
# ---> 63                     walk_to = np.random.choice(walk_options, size=1, p=probabilities)[0]
#      64
#      65                 walk.append(walk_to)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# /usr/local/lib/python3.7/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     363
#     364
# --> 365 @set_module('numpy')
#     366 def issubdtype(arg1, arg2):
#     367     """
#
# KeyboardInterrupt:

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
model1 = node2vec.fit(window=10)
# kmeans clustering을 진행해줍니다.

# %%
K = 5
kmeans = KMeans(n_clusters=K, random_state=0).fit(model1.wv.vectors)
# node의 cluster 부분을 attrdict에 업데이트해줍니다. 
for n, label in zip(model1.wv.index2entity, kmeans.labels_):
    G.nodes[n]['label'] = label

# %%
# 그림을 그려줍니다.
plt.figure(figsize=(30, 30))
nx.draw_networkx(G, pos=nx.layout.spring_layout(G), node_size=node_size,
                 node_color=[n[1]['label'] for n in G.nodes(data=True)], with_labels=False,
                 cmap=plt.cm.rainbow
                )
plt.axis('off')
plt.savefig('../image/network_graph_node2vec_kmeans.png', bbox_inches='tight')
plt.show()
